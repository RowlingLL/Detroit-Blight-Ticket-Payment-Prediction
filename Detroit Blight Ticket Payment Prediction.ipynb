# %% [markdown]
# # Detroit Blight Ticket Payment Prediction
#
# This is based on a data challenge from the Michigan Data Science Team ([MDST](http://midas.umich.edu/mdst/)).
#
# The Michigan Data Science Team ([MDST](http://midas.umich.edu/mdst/)) and the Michigan Student Symposium for Interdisciplinary Statistical Sciences ([MSSISS](https://sites.lsa.umich.edu/mssiss/)) have partnered with the City of Detroit to help solve one of the most pressing problems facing Detroit - blight. [Blight violations](http://www.detroitmi.gov/How-Do-I/Report/Blight-Complaint-FAQs) are issued by the city to individuals who allow their properties to remain in a deteriorated condition. Every year, the city of Detroit issues millions of dollars in fines to residents and every year, many of these fines remain unpaid. Enforcing unpaid blight fines is a costly and tedious process, so the city wants to know: how can we increase blight ticket compliance?
#
# The first step in answering this question is understanding when and why a resident might fail to comply with a blight ticket. This is where predictive modeling comes in. For this assignment, your task is to predict whether a given blight ticket will be paid on time.
#
# All data has been provided through the [Detroit Open Data Portal](https://data.detroitmi.gov/).
# ___
#
#
#
# <br>
#
# **File descriptions**
#
#     train.csv - the training set (all tickets issued 2004-2011)
#     test.csv - the test set (all tickets issued 2012-2016)
#     addresses.csv & latlons.csv - mapping from ticket id to addresses, and from addresses to lat/lon coordinates.
#      Note: misspelled addresses may be incorrectly geolocated.
#
# <br>
#
# **Data fields**
#
# train.csv & test.csv
#
#     ticket_id - unique identifier for tickets
#     agency_name - Agency that issued the ticket
#     inspector_name - Name of inspector that issued the ticket
#     violator_name - Name of the person/organization that the ticket was issued to
#     violation_street_number, violation_street_name, violation_zip_code - Address where the violation occurred
#     mailing_address_str_number, mailing_address_str_name, city, state, zip_code, non_us_str_code, country - Mailing address of the violator
#     ticket_issued_date - Date and time the ticket was issued
#     hearing_date - Date and time the violator's hearing was scheduled
#     violation_code, violation_description - Type of violation
#     disposition - Judgment and judgement type
#     fine_amount - Violation fine amount, excluding fees
#     admin_fee - $20 fee assigned to responsible judgments
# state_fee - $10 fee assigned to responsible judgments
#     late_fee - 10% fee assigned to responsible judgments
#     discount_amount - discount applied, if any
#     clean_up_cost - DPW clean-up or graffiti removal cost
#     judgment_amount - Sum of all fines and fees
#     grafitti_status - Flag for graffiti violations
#
# train.csv only
#
#     payment_amount - Amount paid, if any
#     payment_date - Date payment was made, if it was received
#     payment_status - Current payment status as of Feb 1 2017
#     balance_due - Fines and fees still owed
#     collection_status - Flag for payments in collections
#     compliance [target variable for prediction]
#      Null = Not responsible
#      0 = Responsible, non-compliant
#      1 = Responsible, compliant
#     compliance_detail - More information on why each ticket was marked compliant or non-compliant

# %% [markdown]
# Import the libs needed and have a look at the data. (Note: parse_dates is used here so future processing is easier)

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

train_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1',  dtype={'violation_zip_code':pd.np.str,'zip_code': pd.np.str, 'non_us_str_code': pd.np.str, 'grafitti_status': pd.np.str},parse_dates=[14, 15, 28])
train_data
# Out:
#         ticket_id                                     agency_name  \
# 0           22056  Buildings, Safety Engineering & Env Department
# 1           27586  Buildings, Safety Engineering & Env Department
# 2           22062  Buildings, Safety Engineering & Env Department
# 3           22084  Buildings, Safety Engineering & Env Department
# 4           22093  Buildings, Safety Engineering & Env Department
# 5           22046  Buildings, Safety Engineering & Env Department
# 6           18738  Buildings, Safety Engineering & Env Department
# 7           18735  Buildings, Safety Engineering & Env Department
# 8           18733  Buildings, Safety Engineering & Env Department
# 9           28204  Buildings, Safety Engineering & Env Department
# 10          18739  Buildings, Safety Engineering & Env Department
# 11          18740  Buildings, Safety Engineering & Env Department
# 12          18743  Buildings, Safety Engineering & Env Department
# 13          18741  Buildings, Safety Engineering & Env Department
# 14          18978  Buildings, Safety Engineering & Env Department
# 15          18974  Buildings, Safety Engineering & Env Department
# 16          18742  Buildings, Safety Engineering & Env Department
# 17          28211  Buildings, Safety Engineering & Env Department
# 18          18746  Buildings, Safety Engineering & Env Department
# 19          18744  Buildings, Safety Engineering & Env Department
# 20          18747  Buildings, Safety Engineering & Env Department
# 21          26846  Buildings, Safety Engineering & Env Department
# 22          26848  Buildings, Safety Engineering & Env Department
# 23          28209  Buildings, Safety Engineering & Env Department
# 24          18736  Buildings, Safety Engineering & Env Department
# 25          18737  Buildings, Safety Engineering & Env Department
# 26          19950                               Health Department
# 27          19311                      Department of Public Works
# 28          18645  Buildings, Safety Engineering & Env Department
# 29          19310                      Department of Public Works
# ...           ...                                             ...
# 250276     285037                      Department of Public Works
# 250277     285034                      Department of Public Works
# 250278     285106                      Department of Public Works
# 250279     285040                      Department of Public Works
# 250280     285042                      Department of Public Works
# 250281     285097                      Department of Public Works
# 250282     285098                      Department of Public Works
# 250283     284740  Buildings, Safety Engineering & Env Department
# 250284     284877                       Detroit Police Department
# 250285     284879                      Department of Public Works
# 250286     284880                      Department of Public Works
# 250287     284650                      Department of Public Works
# 250288     285125                      Department of Public Works
# 250289     284647                      Department of Public Works
# 250290     284881                      Department of Public Works
# 250291     284878                      Department of Public Works
# 250292     284338                      Department of Public Works
# 250293     284333                      Department of Public Works
# 250294     284882                       Detroit Police Department
# 250295     284883                       Detroit Police Department
# 250296     366178  Buildings, Safety Engineering & Env Department
# 250297     366176  Buildings, Safety Engineering & Env Department
# 250298     325560  Buildings, Safety Engineering & Env Department
# 250299     325556  Buildings, Safety Engineering & Env Department
# 250300     325558  Buildings, Safety Engineering & Env Department
# 250301     325555  Buildings, Safety Engineering & Env Department
# 250302     325557  Buildings, Safety Engineering & Env Department
# 250303     325562  Buildings, Safety Engineering & Env Department
# 250304     325559  Buildings, Safety Engineering & Env Department
# 250305     325561  Buildings, Safety Engineering & Env Department
#
#                inspector_name                         violator_name  \
# 0             Sims, Martinzie     INVESTMENT INC., MIDWEST MORTGAGE
# 1            Williams, Darrin              Michigan, Covenant House
# 2             Sims, Martinzie                       SANDERS, DERRON
# 3             Sims, Martinzie                          MOROSI, MIKE
# 4             Sims, Martinzie                       NATHANIEL, NEAL
# 5             Sims, Martinzie                        KASIMU, UKWELI
# 6            Williams, Darrin  Deerwood Development Group Inc, Deer
# 7            Williams, Darrin       Rafee Auto Services L.L.C., RAF
# 8            Williams, Darrin       Rafee Auto Services L.L.C., RAF
# 9            Williams, Darrin                            Inc, Nanno
# 10           Williams, Darrin               Mike & Johnny  Inc., MI
# 11           Williams, Darrin                   Karyakous, Samir A.
# 12           Williams, Darrin                   Gardner Resale, GAR
# 13           Williams, Darrin                       Hardaway, Kevin
# 14           Williams, Darrin              TLC Hand Car Wash, a/k/a
# 15           Williams, Darrin                   Gott, Robert Walter
# 16           Williams, Darrin                         Joyner Jr., R
# 17           Williams, Darrin                        Meeks, John O.
# 18           Williams, Darrin                           Klenk, Dean
# 19           Williams, Darrin                            Kuhn, Dean
# 20           Williams, Darrin                        Kuhn, Dean  S.
# 21           Williams, Darrin                       Al-Musawi, Doha
# 22           Williams, Darrin                    Inc., Detrych Tire
# 23           Williams, Darrin                     Allen, Gregory D.
# 24           Williams, Darrin               Pointe Services LTD, PO
# 25           Williams, Darrin              Pointe Services LTD, Poi
# 26                Jones, Leah           CHURCH OF GOD, METROPOLITAN
# 27                Zizi, Josue         00000000000000000000, TRUCARE
# 28            Gailes, Orbie J                            Byrd, Dean
# 29                Zizi, Josue                       JACKSON, ROBERT
# ...                       ...                                   ...
# 250276        McClain, Melvin                         MORRIS, KITAY
# 250277        McClain, Melvin                         MORRIS, KITAY
# 250278            Zizi, Josue                      LUNDY, ANTONIO R
# 250279        McClain, Melvin                    FOWLER, WILLIAM J.
# 250280        McClain, Melvin                    FOWLER, WILLIAM J.
# 250281            Zizi, Josue                     FOWLER, WILLIAM J
# 250282            Zizi, Josue                     FOWLER, WILLIAM J
# 250283         Lockhart, Phil                     WALLER, SR, WAYNE
# 250284       Zawislak, Norbet                 CITGO GAS STATION , .
# 250285          Johnson, Lois                 CO-OP, BABCOCK ELWOOD
# 250286          Johnson, Lois               CO-OP, BABCOCK WESTWOOD
# 250287         Lusk, Gertrina                      HARDAWAY, WILLIE
# 250288          Bell, Maydell         CHRISTIAN CHURCH, BRIGHT STAR
# 250289         Lusk, Gertrina                       COOK, MADONNA M
# 250290          Johnson, Lois                     INC., HANTZ GROUP
# 250291          Johnson, Lois                GREELEY CO-OP, BABCOCK
# 250292     Granberry, Aisha B             CHASE HOME FINANCE LLC, .
# 250293     Granberry, Aisha B     AMERICAN INTERNATIONAL ASS. LL, .
# 250294  Quarello, Christopher                          Gary, Mary A
# 250295       Thornton, Vaughn                          clavon, juan
# 250296           Bush, Wesley                          MARK JACKSON
# 250297           Bush, Wesley                          MARK JACKSON
# 250298           Bush, Wesley       WESTGATE TERRACE APARTMENTS LLC
# 250299           Bush, Wesley       WESTGATE TERRACE APARTMENTS LLC
# 250300           Bush, Wesley       WESTGATE TERRACE APARTMENTS LLC
# 250301           Bush, Wesley       WESTGATE TERRACE APARTMENTS LLC
# 250302           Bush, Wesley       WESTGATE TERRACE APARTMENTS LLC
# 250303           Bush, Wesley       WESTGATE TERRACE APARTMENTS LLC
# 250304           Bush, Wesley       WESTGATE TERRACE APARTMENTS LLC
# 250305           Bush, Wesley       WESTGATE TERRACE APARTMENTS LLC
#
#         violation_street_number violation_street_name violation_zip_code  \
# 0                        2900.0                 TYLER                NaN
# 1                        4311.0               CENTRAL                NaN
# 2                        1449.0            LONGFELLOW                NaN
# 3                        1441.0            LONGFELLOW                NaN
# 4                        2449.0             CHURCHILL                NaN
# 5                        6478.0            NORTHFIELD                NaN
# 6                        8027.0             BRENTWOOD                NaN
# 7                        8228.0            MT ELLIOTT                NaN
# 8                        8228.0            MT ELLIOTT                NaN
# 9                       15307.0            SEVEN MILE                NaN
# 10                      18353.0              VAN DYKE                NaN
# 11                       9500.0              VAN DYKE                NaN
# 12                       9100.0              VAN DYKE                NaN
# 13                      20024.0              SCHAEFER                NaN
# 14                       9425.0              VAN DYKE                NaN
# 15                       9313.0              VAN DYKE                NaN
# 16                       7301.0                HARPER                NaN
# 17                      14935.0                WARREN                NaN
# 18                      14715.0                 KLENK                NaN
# 19                      14715.0                 KLENK                NaN
# 20                      14715.0                 KLENK                NaN
# 21                      16331.0                WARREN                NaN
# 22                       5650.0             LIVERNOIS                NaN
# 23                      15733.0            SEVEN MILE                NaN
# 24                      18701.0                  MACK                NaN
# 25                      18701.0                  MACK                NaN
# 26                      13400.0              SCHAEFER                NaN
# 27                      20525.0             PINEHURST                NaN
# 28                        601.0                  KING                NaN
# 29                      20525.0             PINEHURST                NaN
# ...                         ...                   ...                ...
# 250276                  13924.0              WOODMONT                NaN
# 250277                  13924.0              WOODMONT                NaN
# 250278                  20009.0             NORTHLAWN                NaN
# 250279                  14413.0             GRANDMONT                NaN
# 250280                  14413.0             GRANDMONT                NaN
# 250281                  14413.0             GRANDMONT                NaN
# 250282                  14413.0             GRANDMONT                NaN
# 250283                  17191.0           EDINBOROUGH                NaN
# 250284                   1701.0            GRAND BLVD                NaN
# 250285                  19750.0                  MARX                NaN
# 250286                  19751.0                  MARX                NaN
# 250287                  15725.0                 STEEL                NaN
# 250288                   7152.0               CHICAGO                NaN
# 250289                  19400.0            GREENFIELD                NaN
# 250290                  17403.0            MT ELLIOTT                NaN
# 250291                   1610.0            STATE FAIR                NaN
# 250292                  16211.0                 CORAM                NaN
# 250293                  15634.0                NOVARA                NaN
# 250294                  12210.0              ST MARYS                NaN
# 250295                  19044.0               CHICAGO                NaN
# 250296                   8020.0               PURITAN                NaN
# 250297                   8020.0               PURITAN                NaN
# 250298                  10701.0             MEYERS RD                NaN
# 250299                  10701.0             MEYERS RD                NaN
# 250300                  10701.0             MEYERS RD                NaN
# 250301                  10701.0           SANTA MARIA                NaN
# 250302                  10701.0             MEYERS RD                NaN
# 250303                  10701.0             MEYERS RD                NaN
# 250304                  10701.0             MEYERS RD                NaN
# 250305                  10701.0             MEYERS RD                NaN
#
#         mailing_address_str_number mailing_address_str_name         city  ...  \
# 0                              3.0                S. WICKER      CHICAGO  ...
# 1                           2959.0       Martin Luther King      Detroit  ...
# 2                          23658.0                 P.O. BOX      DETROIT  ...
# 3                              5.0                ST. CLAIR      DETROIT  ...
# 4                           7449.0                CHURCHILL      DETROIT  ...
# 5                           2755.0                  E. 17TH    LOG BEACH  ...
# 6                            476.0                 Garfield      Clinton  ...
# 7                           8228.0              Mt. Elliott      Detroit  ...
# 8                           8228.0              Mt. Elliott      Detroit  ...
# 9                           1537.0            E. Seven Mile      Detroit  ...
# 10                         18353.0                 Van Dyke      Detroit  ...
# 11                           229.0               Brookfield       Canton  ...
# 12                            91.0                 Van Dyke      Detroit  ...
# 13                           224.0                 Schaefer      Detroit  ...
# 14                          9425.0                 Van Dyke      Detroit  ...
# 15                           275.0                  Ardsley   Ortonville  ...
# 16                          9669.0                  Balfour      Detroit  ...
# 17                         14935.0                E. Warren      Detroit  ...
# 18                         14715.0                    Klenk      Detroit  ...
# 19                        141715.0                    Klenk      Detroit  ...
# 20                         14715.0                    Klenk      Detroit  ...
# 21                         16331.0                W. Warren      Detroit  ...
# 22                           565.0                Livernois      Detroit  ...
# 23                         15735.0            E. Seven Mile      Detroit  ...
# 24                          1871.0                     Mack      Detroit  ...
# 25                          1871.0                     Mack      Detroit  ...
# 26                           134.0                  SCHAFER      DETROIT  ...
# 27                          2913.0            UNIVERSAL AVE  EAST POINTE  ...
# 28                           599.0                     King          Det  ...
# 29                         19136.0                  INDIANA      DETROIT  ...
# ...                            ...                      ...          ...  ...
# 250276                     13924.0             WOODMONT AVE      DETROIT  ...
# 250277                     13924.0             WOODMONT AVE      DETROIT  ...
# 250278                     18715.0                  MARLOWE      DETROIT  ...
# 250279                       276.0                  KENDALL      DETROIT  ...
# 250280                       276.0                  KENDALL      DETROIT  ...
# 250281                       324.0                   SPRUCE      INKSTER  ...
# 250282                       324.0                   SPRUCE      INKSTER  ...
# 250283                     28398.0             LADY K COURT   SOUTHFIELD  ...
# 250284                       171.0              E GRANDBLVD      DETROIT  ...
# 250285                       645.0                 LOZON RD  MARINE CITY  ...
# 250286                       645.0                 LOZON RD  MARINE CITY  ...
# 250287                         NaN           P.O. BOX 27125      DETROIT  ...
# 250288                      7152.0               W. CHICAGO      DETROIT  ...
# 250289                      1921.0                    AFTON      DETROIT  ...
# 250290                      1743.0               MT ELLIOTT      DETROIT  ...
# 250291                       111.0       CADILLAC SQ.  #310      DETROIT  ...
# 250292                         8.0          BROOKSEDGE BLVD  WESTERVILLE  ...
# 250293                        72.0                 MANGROVE        CHICO  ...
# 250294                      1629.0              Asbury Park      Detroit  ...
# 250295                       726.0                  bethune      detroit  ...
# 250296                       251.0                   HEYDEN       DETROT  ...
# 250297                       251.0                   HEYDEN       DETROT  ...
# 250298                      1715.0                   MEYERS      DETROIT  ...
# 250299                      1715.0                   MEYERS      DETROIT  ...
# 250300                      1715.0                   MEYERS      DETROIT  ...
# 250301                      1715.0                   MEYERS      DETROIT  ...
# 250302                      1715.0                   MEYERS      DETROIT  ...
# 250303                      1715.0                   MEYERS      DETROIT  ...
# 250304                      1715.0                   MEYERS      DETROIT  ...
# 250305                      1715.0                   MEYERS      DETROIT  ...
#
#        clean_up_cost judgment_amount payment_amount balance_due payment_date  \
# 0                0.0           305.0            0.0       305.0          NaT
# 1                0.0           855.0          780.0        75.0   2005-06-02
# 2                0.0             0.0            0.0         0.0          NaT
# 3                0.0             0.0            0.0         0.0          NaT
# 4                0.0             0.0            0.0         0.0          NaT
# 5                0.0           305.0            0.0       305.0          NaT
# 6                0.0           855.0            0.0       855.0          NaT
# 7                0.0           140.0            0.0       140.0          NaT
# 8                0.0           140.0            0.0       140.0          NaT
# 9                0.0           855.0            0.0       855.0          NaT
# 10               0.0             0.0            0.0         0.0          NaT
# 11               0.0             0.0          130.0         0.0   2005-03-17
# 12               0.0           855.0            0.0       855.0          NaT
# 13               0.0           855.0            0.0       855.0          NaT
# 14               0.0           855.0            0.0       855.0          NaT
# 15               0.0             0.0           75.0         0.0   2005-02-11
# 16               0.0             0.0            0.0         0.0          NaT
# 17               0.0             0.0            0.0         0.0          NaT
# 18               0.0           140.0          130.0        10.0   2005-03-18
# 19               0.0           140.0          130.0        10.0   2005-03-18
# 20               0.0             0.0            0.0         0.0          NaT
# 21               0.0           855.0            0.0       855.0          NaT
# 22               0.0           855.0            0.0       855.0          NaT
# 23               0.0           855.0            0.0       855.0          NaT
# 24               0.0             0.0            0.0         0.0          NaT
# 25               0.0             0.0          130.0         0.0   2005-02-18
# 26               0.0           130.0          120.0        10.0   2010-01-26
# 27               0.0             0.0            0.0         0.0          NaT
# 28               0.0           305.0            0.0       305.0          NaT
# 29               0.0             0.0            0.0         0.0          NaT
# ...              ...             ...            ...         ...          ...
# 250276           0.0           140.0            0.0       140.0          NaT
# 250277           0.0           580.0            0.0       580.0          NaT
# 250278           0.0           250.0            0.0       250.0          NaT
# 250279           0.0             0.0            0.0         0.0          NaT
# 250280           0.0             0.0            0.0         0.0          NaT
# 250281           0.0             0.0            0.0         0.0          NaT
# 250282           0.0             0.0            0.0         0.0          NaT
# 250283           0.0             0.0            0.0         0.0          NaT
# 250284           0.0             0.0            0.0         0.0          NaT
# 250285           0.0             0.0            0.0         0.0          NaT
# 250286           0.0             0.0            0.0         0.0          NaT
# 250287           0.0          1130.0            0.0      1130.0          NaT
# 250288           0.0           580.0            0.0       580.0          NaT
# 250289           0.0             0.0            0.0         0.0          NaT
# 250290           0.0           230.0          230.0         0.0   2012-02-07
# 250291           0.0             0.0            0.0         0.0          NaT
# 250292           0.0             0.0            0.0         0.0          NaT
# 250293           0.0           250.0            0.0       250.0          NaT
# 250294           0.0             0.0            0.0         0.0          NaT
# 250295           0.0             0.0            0.0         0.0          NaT
# 250296           0.0             0.0            0.0         0.0          NaT
# 250297           0.0             0.0            0.0         0.0          NaT
# 250298           0.0             0.0            0.0         0.0          NaT
# 250299           0.0             0.0            0.0         0.0          NaT
# 250300           0.0             0.0            0.0         0.0          NaT
# 250301           0.0             0.0            0.0         0.0          NaT
# 250302           0.0             0.0            0.0         0.0          NaT
# 250303           0.0             0.0            0.0         0.0          NaT
# 250304           0.0             0.0            0.0         0.0          NaT
# 250305           0.0             0.0            0.0         0.0          NaT
#
#                  payment_status collection_status  grafitti_status  \
# 0            NO PAYMENT APPLIED               NaN              NaN
# 1                  PAID IN FULL               NaN              NaN
# 2            NO PAYMENT APPLIED               NaN              NaN
# 3            NO PAYMENT APPLIED               NaN              NaN
# 4            NO PAYMENT APPLIED               NaN              NaN
# 5            NO PAYMENT APPLIED               NaN              NaN
# 6            NO PAYMENT APPLIED               NaN              NaN
# 7            NO PAYMENT APPLIED               NaN              NaN
# 8            NO PAYMENT APPLIED               NaN              NaN
# 9            NO PAYMENT APPLIED               NaN              NaN
# 10           NO PAYMENT APPLIED               NaN              NaN
# 11                 PAID IN FULL               NaN              NaN
# 12           NO PAYMENT APPLIED     IN COLLECTION              NaN
# 13           NO PAYMENT APPLIED     IN COLLECTION              NaN
# 14           NO PAYMENT APPLIED               NaN              NaN
# 15                 PAID IN FULL               NaN              NaN
# 16           NO PAYMENT APPLIED               NaN              NaN
# 17           NO PAYMENT APPLIED               NaN              NaN
# 18                 PAID IN FULL               NaN              NaN
# 19                 PAID IN FULL               NaN              NaN
# 20           NO PAYMENT APPLIED               NaN              NaN
# 21           NO PAYMENT APPLIED               NaN              NaN
# 22           NO PAYMENT APPLIED     IN COLLECTION              NaN
# 23           NO PAYMENT APPLIED               NaN              NaN
# 24           NO PAYMENT APPLIED               NaN              NaN
# 25                 PAID IN FULL               NaN              NaN
# 26      PARTIAL PAYMENT APPLIED               NaN              NaN
# 27           NO PAYMENT APPLIED               NaN              NaN
# 28           NO PAYMENT APPLIED               NaN              NaN
# 29           NO PAYMENT APPLIED               NaN              NaN
# ...                         ...               ...              ...
# 250276       NO PAYMENT APPLIED               NaN              NaN
# 250277       NO PAYMENT APPLIED               NaN              NaN
# 250278       NO PAYMENT APPLIED               NaN              NaN
# 250279       NO PAYMENT APPLIED               NaN              NaN
# 250280       NO PAYMENT APPLIED               NaN              NaN
# 250281       NO PAYMENT APPLIED               NaN              NaN
# 250282       NO PAYMENT APPLIED               NaN              NaN
# 250283       NO PAYMENT APPLIED               NaN              NaN
# 250284       NO PAYMENT APPLIED               NaN              NaN
# 250285       NO PAYMENT APPLIED               NaN              NaN
# 250286       NO PAYMENT APPLIED               NaN              NaN
# 250287       NO PAYMENT APPLIED     IN COLLECTION              NaN
# 250288       NO PAYMENT APPLIED               NaN              NaN
# 250289       NO PAYMENT APPLIED               NaN              NaN
# 250290             PAID IN FULL               NaN              NaN
# 250291       NO PAYMENT APPLIED               NaN              NaN
# 250292       NO PAYMENT APPLIED               NaN              NaN
# 250293       NO PAYMENT APPLIED               NaN              NaN
# 250294       NO PAYMENT APPLIED               NaN              NaN
# 250295       NO PAYMENT APPLIED               NaN              NaN
# 250296       NO PAYMENT APPLIED               NaN  GRAFFITI TICKET
# 250297       NO PAYMENT APPLIED               NaN              NaN
# 250298       NO PAYMENT APPLIED               NaN              NaN
# 250299       NO PAYMENT APPLIED               NaN              NaN
# 250300       NO PAYMENT APPLIED               NaN              NaN
# 250301       NO PAYMENT APPLIED               NaN              NaN
# 250302       NO PAYMENT APPLIED               NaN              NaN
# 250303       NO PAYMENT APPLIED               NaN              NaN
# 250304       NO PAYMENT APPLIED               NaN              NaN
# 250305       NO PAYMENT APPLIED               NaN              NaN
#
#                                       compliance_detail  compliance
# 0                           non-compliant by no payment         0.0
# 1              compliant by late payment within 1 month         1.0
# 2                        not responsible by disposition         NaN
# 3                        not responsible by disposition         NaN
# 4                        not responsible by disposition         NaN
# 5                           non-compliant by no payment         0.0
# 6                           non-compliant by no payment         0.0
# 7                           non-compliant by no payment         0.0
# 8                           non-compliant by no payment         0.0
# 9                           non-compliant by no payment         0.0
# 10                       not responsible by disposition         NaN
# 11                       not responsible by disposition         NaN
# 12                          non-compliant by no payment         0.0
# 13                          non-compliant by no payment         0.0
# 14                          non-compliant by no payment         0.0
# 15      not responsible by pending judgment disposition         NaN
# 16                       not responsible by disposition         NaN
# 17                       not responsible by disposition         NaN
# 18             compliant by late payment within 1 month         1.0
# 19             compliant by late payment within 1 month         1.0
# 20                       not responsible by disposition         NaN
# 21                          non-compliant by no payment         0.0
# 22                          non-compliant by no payment         0.0
# 23                          non-compliant by no payment         0.0
# 24                       not responsible by disposition         NaN
# 25      not responsible by pending judgment disposition         NaN
# 26                          non-compliant by no payment         0.0
# 27                       not responsible by disposition         NaN
# 28                          non-compliant by no payment         0.0
# 29                       not responsible by disposition         NaN
# ...                                                 ...         ...
# 250276                      non-compliant by no payment         0.0
# 250277                      non-compliant by no payment         0.0
# 250278                      non-compliant by no payment         0.0
# 250279                   not responsible by disposition         NaN
# 250280                   not responsible by disposition         NaN
# 250281                   not responsible by disposition         NaN
# 250282                   not responsible by disposition         NaN
# 250283                   not responsible by disposition         NaN
# 250284                   not responsible by disposition         NaN
# 250285                   not responsible by disposition         NaN
# 250286                   not responsible by disposition         NaN
# 250287                      non-compliant by no payment         0.0
# 250288                      non-compliant by no payment         0.0
# 250289                   not responsible by disposition         NaN
# 250290                     compliant by on-time payment         1.0
# 250291                   not responsible by disposition         NaN
# 250292                   not responsible by disposition         NaN
# 250293                      non-compliant by no payment         0.0
# 250294                   not responsible by disposition         NaN
# 250295                   not responsible by disposition         NaN
# 250296                   not responsible by disposition         NaN
# 250297                   not responsible by disposition         NaN
# 250298                   not responsible by disposition         NaN
# 250299                   not responsible by disposition         NaN
# 250300                   not responsible by disposition         NaN
# 250301                   not responsible by disposition         NaN
# 250302                   not responsible by disposition         NaN
# 250303                   not responsible by disposition         NaN
# 250304                   not responsible by disposition         NaN
# 250305                   not responsible by disposition         NaN
#
# [250306 rows x 34 columns]

# %%
train_data.describe(include='all').T
# Out:
#                              count  unique  \
# ticket_id                   250306     NaN
# agency_name                 250306       5
# inspector_name              250306     173
# violator_name               250272  119992
# violation_street_number     250306     NaN
# violation_street_name       250306    1791
# violation_zip_code               0       0
# mailing_address_str_number  246704     NaN
# mailing_address_str_name    250302   37896
# city                        250306    5184
# state                       250213      59
# zip_code                    250305    4251
# non_us_str_code                  3       2
# country                     250306       5
# ticket_issued_date          250306   86979
# hearing_date                237815    6222
# violation_code              250306     235
# violation_description       250306     258
# disposition                 250306       9
# fine_amount                 250305     NaN
# admin_fee                   250306     NaN
# state_fee                   250306     NaN
# late_fee                    250306     NaN
# discount_amount             250306     NaN
# clean_up_cost               250306     NaN
# judgment_amount             250306     NaN
# payment_amount              250306     NaN
# balance_due                 250306     NaN
# payment_date                 41113    2307
# payment_status              250306       3
# collection_status            36897       1
# grafitti_status                  1       1
# compliance_detail           250306      10
# compliance                  159880     NaN
#
#                                                                           top  \
# ticket_id                                                                 NaN
# agency_name                    Buildings, Safety Engineering & Env Department
# inspector_name                                                   Morris, John
# violator_name                                               INVESTMENT, ACORN
# violation_street_number                                                   NaN
# violation_street_name                                              SEVEN MILE
# violation_zip_code                                                        NaN
# mailing_address_str_number                                                NaN
# mailing_address_str_name                                               PO BOX
# city                                                                  DETROIT
# state                                                                      MI
# zip_code                                                                48227
# non_us_str_code                                               ONTARIO, Canada
# country                                                                   USA
# ticket_issued_date                                        2010-02-17 09:00:00
# hearing_date                                              2005-12-22 10:30:00
# violation_code                                                      9-1-36(a)
# violation_description       Failure of owner to obtain certificate of comp...
# disposition                                            Responsible by Default
# fine_amount                                                               NaN
# admin_fee                                                                 NaN
# state_fee                                                                 NaN
# late_fee                                                                  NaN
# discount_amount                                                           NaN
# clean_up_cost                                                             NaN
# judgment_amount                                                           NaN
# payment_amount                                                            NaN
# balance_due                                                               NaN
# payment_date                                              2014-08-04 00:00:00
# payment_status                                             NO PAYMENT APPLIED
# collection_status                                               IN COLLECTION
# grafitti_status                                               GRAFFITI TICKET
# compliance_detail                                 non-compliant by no payment
# compliance                                                                NaN
#
#                               freq                first                 last  \
# ticket_id                      NaN                  NaN                  NaN
# agency_name                 157784                  NaN                  NaN
# inspector_name               17926                  NaN                  NaN
# violator_name                  809                  NaN                  NaN
# violation_street_number        NaN                  NaN                  NaN
# violation_street_name         3482                  NaN                  NaN
# violation_zip_code             NaN                  NaN                  NaN
# mailing_address_str_number     NaN                  NaN                  NaN
# mailing_address_str_name      8668                  NaN                  NaN
# city                        136936                  NaN                  NaN
# state                       228601                  NaN                  NaN
# zip_code                     11617                  NaN                  NaN
# non_us_str_code                  2                  NaN                  NaN
# country                     250293                  NaN                  NaN
# ticket_issued_date              97  1938-10-09 15:30:00  2011-12-31 16:15:00
# hearing_date                   622  2005-01-27 09:00:00  2017-01-27 10:30:00
# violation_code               99091                  NaN                  NaN
# violation_description        99091                  NaN                  NaN
# disposition                 138340                  NaN                  NaN
# fine_amount                    NaN                  NaN                  NaN
# admin_fee                      NaN                  NaN                  NaN
# state_fee                      NaN                  NaN                  NaN
# late_fee                       NaN                  NaN                  NaN
# discount_amount                NaN                  NaN                  NaN
# clean_up_cost                  NaN                  NaN                  NaN
# judgment_amount                NaN                  NaN                  NaN
# payment_amount                 NaN                  NaN                  NaN
# balance_due                    NaN                  NaN                  NaN
# payment_date                   177  2005-01-25 00:00:00  2017-01-25 00:00:00
# payment_status              209193                  NaN                  NaN
# collection_status            36897                  NaN                  NaN
# grafitti_status                  1                  NaN                  NaN
# compliance_detail           129267                  NaN                  NaN
# compliance                     NaN                  NaN                  NaN
#
#                                  mean       std    min      25%     50%  \
# ticket_id                      152666   77189.9  18645  86549.2  152598
# agency_name                       NaN       NaN    NaN      NaN     NaN
# inspector_name                    NaN       NaN    NaN      NaN     NaN
# violator_name                     NaN       NaN    NaN      NaN     NaN
# violation_street_number       10649.9   31887.3      0     4739   10244
# violation_street_name             NaN       NaN    NaN      NaN     NaN
# violation_zip_code                NaN       NaN    NaN      NaN     NaN
# mailing_address_str_number    9149.79   36020.3      1      544    2456
# mailing_address_str_name          NaN       NaN    NaN      NaN     NaN
# city                              NaN       NaN    NaN      NaN     NaN
# state                             NaN       NaN    NaN      NaN     NaN
# zip_code                          NaN       NaN    NaN      NaN     NaN
# non_us_str_code                   NaN       NaN    NaN      NaN     NaN
# country                           NaN       NaN    NaN      NaN     NaN
# ticket_issued_date                NaN       NaN    NaN      NaN     NaN
# hearing_date                      NaN       NaN    NaN      NaN     NaN
# violation_code                    NaN       NaN    NaN      NaN     NaN
# violation_description             NaN       NaN    NaN      NaN     NaN
# disposition                       NaN       NaN    NaN      NaN     NaN
# fine_amount                   374.423   707.196      0      200     250
# admin_fee                     12.7748   9.60734      0        0      20
# state_fee                     6.38738   4.80367      0        0      10
# late_fee                      21.4945   56.4643      0        0      10
# discount_amount              0.125167   3.43018      0        0       0
# clean_up_cost                       0         0      0        0       0
# judgment_amount               268.685   626.915      0        0     140
# payment_amount                 48.899   222.422      0        0       0
# balance_due                   222.449   606.394  -7750        0      25
# payment_date                      NaN       NaN    NaN      NaN     NaN
# payment_status                    NaN       NaN    NaN      NaN     NaN
# collection_status                 NaN       NaN    NaN      NaN     NaN
# grafitti_status                   NaN       NaN    NaN      NaN     NaN
# compliance_detail                 NaN       NaN    NaN      NaN     NaN
# compliance                  0.0725357  0.259374      0        0       0
#
#                                 75%          max
# ticket_id                    219889       366178
# agency_name                     NaN          NaN
# inspector_name                  NaN          NaN
# violator_name                   NaN          NaN
# violation_street_number       15760  1.41541e+07
# violation_street_name           NaN          NaN
# violation_zip_code              NaN          NaN
# mailing_address_str_number  12927.2  5.11134e+06
# mailing_address_str_name        NaN          NaN
# city                            NaN          NaN
# state                           NaN          NaN
# zip_code                        NaN          NaN
# non_us_str_code                 NaN          NaN
# country                         NaN          NaN
# ticket_issued_date              NaN          NaN
# hearing_date                    NaN          NaN
# violation_code                  NaN          NaN
# violation_description           NaN          NaN
# disposition                     NaN          NaN
# fine_amount                     250        10000
# admin_fee                        20           20
# state_fee                        10           10
# late_fee                         25         1000
# discount_amount                   0          350
# clean_up_cost                     0            0
# judgment_amount                 305        11030
# payment_amount                    0        11075
# balance_due                     305        11030
# payment_date                    NaN          NaN
# payment_status                  NaN          NaN
# collection_status               NaN          NaN
# grafitti_status                 NaN          NaN
# compliance_detail               NaN          NaN
# compliance                        0            1

# %% [markdown]
# Based on the description above, some columns/rows are dropped as they are not likely good predictors, or too good that could cause leakage.

# %%
train_data=train_data[(train_data['compliance'] == 1) |(train_data['compliance'] == 0)]
train_data=train_data.drop(columns=['payment_amount','violator_name','balance_due','mailing_address_str_name','payment_date','violation_description','violation_street_number','payment_status','collection_status','compliance_detail'])
train_data.shape
# Out:
# (159880, 24)

# %% [markdown]
# The waittime between ticket issue date and hearing date is more relevant than the actual date. Some people may need more time to prepare the money:)

# %%
train_data['waittime'] = (train_data['hearing_date']-train_data['ticket_issued_date']).dt.days
train_data.describe(include='all').T
# Out:
#                              count unique  \
# ticket_id                   159880    NaN
# agency_name                 159880      5
# inspector_name              159880    159
# violation_street_name       159880   1716
# violation_zip_code               0      0
# mailing_address_str_number  157322    NaN
# city                        159880   4093
# state                       159796     59
# zip_code                    159879   3498
# non_us_str_code                  3      2
# country                     159880      5
# ticket_issued_date          159880  68097
# hearing_date                159653   5970
# violation_code              159880    189
# disposition                 159880      4
# fine_amount                 159880    NaN
# admin_fee                   159880    NaN
# state_fee                   159880    NaN
# late_fee                    159880    NaN
# discount_amount             159880    NaN
# clean_up_cost               159880    NaN
# judgment_amount             159880    NaN
# grafitti_status                  0      0
# compliance                  159880    NaN
# waittime                    159653    NaN
#
#                                                                        top  \
# ticket_id                                                              NaN
# agency_name                 Buildings, Safety Engineering & Env Department
# inspector_name                                                Morris, John
# violation_street_name                                           SEVEN MILE
# violation_zip_code                                                     NaN
# mailing_address_str_number                                             NaN
# city                                                               DETROIT
# state                                                                   MI
# zip_code                                                             48227
# non_us_str_code                                            ONTARIO, Canada
# country                                                                USA
# ticket_issued_date                                     2007-12-21 09:00:00
# hearing_date                                           2005-12-20 09:00:00
# violation_code                                                   9-1-36(a)
# disposition                                         Responsible by Default
# fine_amount                                                            NaN
# admin_fee                                                              NaN
# state_fee                                                              NaN
# late_fee                                                               NaN
# discount_amount                                                        NaN
# clean_up_cost                                                          NaN
# judgment_amount                                                        NaN
# grafitti_status                                                        NaN
# compliance                                                             NaN
# waittime                                                               NaN
#
#                               freq                first                 last  \
# ticket_id                      NaN                  NaN                  NaN
# agency_name                  95863                  NaN                  NaN
# inspector_name               11604                  NaN                  NaN
# violation_street_name         2373                  NaN                  NaN
# violation_zip_code             NaN                  NaN                  NaN
# mailing_address_str_number     NaN                  NaN                  NaN
# city                         87426                  NaN                  NaN
# state                       143655                  NaN                  NaN
# zip_code                      7316                  NaN                  NaN
# non_us_str_code                  2                  NaN                  NaN
# country                     159869                  NaN                  NaN
# ticket_issued_date              60  1988-05-06 20:00:00  2011-12-30 14:20:00
# hearing_date                   590  2005-01-27 09:00:00  2016-11-22 09:00:00
# violation_code               64414                  NaN                  NaN
# disposition                 138340                  NaN                  NaN
# fine_amount                    NaN                  NaN                  NaN
# admin_fee                      NaN                  NaN                  NaN
# state_fee                      NaN                  NaN                  NaN
# late_fee                       NaN                  NaN                  NaN
# discount_amount                NaN                  NaN                  NaN
# clean_up_cost                  NaN                  NaN                  NaN
# judgment_amount                NaN                  NaN                  NaN
# grafitti_status                NaN                  NaN                  NaN
# compliance                     NaN                  NaN                  NaN
# waittime                       NaN                  NaN                  NaN
#
#                                  mean       std    min      25%     50%  \
# ticket_id                      150454   77224.7  18645  83370.8  149778
# agency_name                       NaN       NaN    NaN      NaN     NaN
# inspector_name                    NaN       NaN    NaN      NaN     NaN
# violation_street_name             NaN       NaN    NaN      NaN     NaN
# violation_zip_code                NaN       NaN    NaN      NaN     NaN
# mailing_address_str_number    9133.71   36577.3      1      532    2418
# city                              NaN       NaN    NaN      NaN     NaN
# state                             NaN       NaN    NaN      NaN     NaN
# zip_code                          NaN       NaN    NaN      NaN     NaN
# non_us_str_code                   NaN       NaN    NaN      NaN     NaN
# country                           NaN       NaN    NaN      NaN     NaN
# ticket_issued_date                NaN       NaN    NaN      NaN     NaN
# hearing_date                      NaN       NaN    NaN      NaN     NaN
# violation_code                    NaN       NaN    NaN      NaN     NaN
# disposition                       NaN       NaN    NaN      NaN     NaN
# fine_amount                   357.035   675.656      0      200     250
# admin_fee                          20         0     20       20      20
# state_fee                          10         0     10       10      10
# late_fee                      33.6515   67.6929      0       10      25
# discount_amount              0.195959   4.29034      0        0       0
# clean_up_cost                       0         0      0        0       0
# judgment_amount                420.65   742.555      0      250     305
# grafitti_status                   NaN       NaN    NaN      NaN     NaN
# compliance                  0.0725357  0.259374      0        0       0
# waittime                      72.6474   62.6659   -337       30      54
#
#                                75%          max
# ticket_id                   217480       299363
# agency_name                    NaN          NaN
# inspector_name                 NaN          NaN
# violation_street_name          NaN          NaN
# violation_zip_code             NaN          NaN
# mailing_address_str_number   12844  5.11134e+06
# city                           NaN          NaN
# state                          NaN          NaN
# zip_code                       NaN          NaN
# non_us_str_code                NaN          NaN
# country                        NaN          NaN
# ticket_issued_date             NaN          NaN
# hearing_date                   NaN          NaN
# violation_code                 NaN          NaN
# disposition                    NaN          NaN
# fine_amount                    250        10000
# admin_fee                       20           20
# state_fee                       10           10
# late_fee                        25         1000
# discount_amount                  0          350
# clean_up_cost                    0            0
# judgment_amount                305        11030
# grafitti_status                NaN          NaN
# compliance                       0            1
# waittime                       100         7933

# %% [markdown]
# There are negative values and extreme high values for the waittime, that's weird. Let's have a look.

# %%
train_data['waittime'].hist(bins=1000)
# Out:
# <div id='4ba78602-9e7b-45c4-bb6f-da91212742cc'></div>

# %%
#remove outliers
train_data['waittime']=train_data['waittime'].apply(lambda x: 72 if x>365 or x<0 else x)
train_data['waittime'].fillna(train_data['waittime'].mean())
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159880 entries, 0 to 250293
# Data columns (total 25 columns):
# ticket_id                     159880 non-null int64
# agency_name                   159880 non-null object
# inspector_name                159880 non-null object
# violation_street_name         159880 non-null object
# violation_zip_code            0 non-null object
# mailing_address_str_number    157322 non-null float64
# city                          159880 non-null object
# state                         159796 non-null object
# zip_code                      159879 non-null object
# non_us_str_code               3 non-null object
# country                       159880 non-null object
# ticket_issued_date            159880 non-null datetime64[ns]
# hearing_date                  159653 non-null datetime64[ns]
# violation_code                159880 non-null object
# disposition                   159880 non-null object
# fine_amount                   159880 non-null float64
# admin_fee                     159880 non-null float64
# state_fee                     159880 non-null float64
# late_fee                      159880 non-null float64
# discount_amount               159880 non-null float64
# clean_up_cost                 159880 non-null float64
# judgment_amount               159880 non-null float64
# grafitti_status               0 non-null object
# compliance                    159880 non-null float64
# waittime                      159653 non-null float64
# dtypes: datetime64[ns](2), float64(10), int64(1), object(12)
# memory usage: 31.7+ MB

# %%
test_data = pd.read_csv("test.csv", encoding = 'ISO-8859-1',  dtype={'zip_code': pd.np.str, 'non_us_str_code': pd.np.str, 'grafitti_status': pd.np.str},parse_dates=[14,15])

test_data['waittime'] = (test_data['hearing_date']-test_data['ticket_issued_date']).dt.days

# %% [markdown]
# For the features with type 'object',choose the irrelavant ones to drop, and relavant ones to convert

# %%
list_to_remove=['inspector_name','zip_code','violation_zip_code','mailing_address_str_number','violation_street_name','state','city','non_us_str_code','ticket_issued_date','hearing_date','grafitti_status']
dummies=['agency_name','country','violation_code','disposition']    
train_data.drop(list_to_remove,axis=1,inplace=True)
train_data=train_data.fillna(0)
train_data=pd.get_dummies(train_data,columns=dummies)

test_data.drop(list_to_remove,axis=1,inplace=True)
test_data=test_data.drop(columns=['violator_name','mailing_address_str_name','violation_description','violation_street_number'])
test_data=test_data.fillna(0)
test_data=pd.get_dummies(test_data,columns=dummies)

# %%
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159880 entries, 0 to 250293
# Columns: 213 entries, ticket_id to disposition_Responsible by Determination
# dtypes: float64(9), int64(1), uint8(203)
# memory usage: 44.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61001 entries, 0 to 61000
# Columns: 172 entries, ticket_id to disposition_Responsible by Dismissal
# dtypes: float64(8), int64(1), uint8(163)
# memory usage: 13.7 MB

# %%
train_data.columns.get_duplicates()
# Out:
# /Users/Fall/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'get_duplicates' is deprecated and will be removed in a future release. You can use idx[idx.duplicated()].unique() instead
#   """Entry point for launching an IPython kernel.
# Index([], dtype='object')

# %%
#These are the train/test sets for real
train_features = train_data.columns.drop('compliance')

train_features_set = set(train_features)
for feature in set(train_features):
    if feature not in test_data:
        train_features_set.remove(feature)
train_features = list(train_features_set)
     
X_realtrain = train_data[train_features]
y_realtrain = train_data.compliance
X_realtest = test_data[train_features]

scaler = MinMaxScaler()
X_realtrain_scaled = scaler.fit_transform(X_realtrain)
X_realtest_scaled = scaler.transform(X_realtest)
# Out:
# /Users/Fall/anaconda3/envs/tf/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
#These are splits for my own testing 
X=X_realtrain_scaled
y=y_realtrain
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
X_train.shape,y_train.shape
# Out:
# ((119910, 134), (119910,))

# %% [markdown]
# Testing Naive Bayes model

# %%
def NB_test():
    NBmodel = GaussianNB().fit(X_train, y_train)
    
    y_pred = NBmodel.predict(X_test)
    
    score = roc_auc_score(y_test, y_pred)
    return score

NB_test()
# Out:
# 0.5047888187117331

# %% [markdown]
# Testing RandomForest model

# %%
def RF_test():
    
    rfc=RandomForestClassifier(random_state=0)
    
    param_grid = { 
    'n_estimators': [200,500,700],
    'max_features': ['auto'],
    'max_depth' : [6,8,10,12],
    'criterion' :['gini', 'entropy']
    }
    
    CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, scoring='roc_auc', cv= 5)
    CV_rfc.fit(X_train, y_train)
    
    
    y_pred=CV_rfc.predict(X_test)
    
    score = roc_auc_score(y_test, y_pred)
    return CV_rfc.best_params_, score
    
RF_test()
# Out:
# ({'criterion': 'entropy',
#   'max_depth': 12,
#   'max_features': 'auto',
#   'n_estimators': 700},
#  0.6192579741246016)

# %%
def MLP():
    
    MLPclf=MLPClassifier(random_state=0)
    parameters = {'solver': ['lbfgs'], 
                  'max_iter': [100,200,400], 
                  'alpha': [0.001, 0.01, 1,10], 
                  'hidden_layer_sizes':np.arange(10, 15)
                 }
    
    CV_MLPclf = GridSearchCV(MLPClassifier(), parameters, scoring='roc_auc', n_jobs=-1)

    CV_MLPclf.fit(X_train, y_train)
    y_pred=CV_MLPclf.predict(X_test)
    
    score = roc_auc_score(y_test, y_pred)
    return CV_MLPclf.best_params_, score
MLP()
# Out:
# /Users/Fall/anaconda3/envs/tf/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# ({'alpha': 0.001,
#   'hidden_layer_sizes': 14,
#   'max_iter': 400,
#   'solver': 'lbfgs'},
#  0.6093862946916809)
